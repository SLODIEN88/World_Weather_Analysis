# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
import requests
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
                                                      
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | laguna
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | illapel
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | ekhabi
# Processing Record 11 of Set 1 | mandalgovi
# Processing Record 12 of Set 1 | carbondale
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | vanimo
# Processing Record 17 of Set 1 | erenhot
# Processing Record 18 of Set 1 | touros
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | pundaguitan
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | taltal
# Processing Record 27 of Set 1 | kangaatsiaq
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | tateyama
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | svetlogorsk
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | nabire
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | lac du bonnet
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | dwarka
# Processing Record 43 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 1 | pochutla
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | tucurui
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | marsh harbour
# Processing Record 50 of Set 1 | seddon
# Processing Record 1 of Set 2 | merauke
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | darhan
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | sur
# Processing Record 6 of Set 2 | port lincoln
# Processing Record 7 of Set 2 | song phi nong
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | ibadan
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | praya
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | mayo
# Processing Record 14 of Set 2 | puerto escondido
# Processing Record 15 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 2 | esqueda
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | minas
# Processing Record 21 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 2 | surt
# Processing Record 23 of Set 2 | igunga
# Processing Record 24 of Set 2 | simoes
# Processing Record 25 of Set 2 | eldama ravine
# Processing Record 26 of Set 2 | ostersund
# Processing Record 27 of Set 2 | rock hill
# Processing Record 28 of Set 2 | nouakchott
# Processing Record 29 of Set 2 | necochea
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | aanekoski
# Processing Record 32 of Set 2 | busselton
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | khash
# Processing Record 36 of Set 2 | uruzgan
# Processing Record 37 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | sisimiut
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | dekar
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | dapaong
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | la gomera
# Processing Record 47 of Set 2 | yaan
# Processing Record 48 of Set 2 | bara
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | kondinskoye
# Processing Record 3 of Set 3 | walajabad
# City not found. Skipping...
# Processing Record 4 of Set 3 | cairns
# Processing Record 5 of Set 3 | port macquarie
# Processing Record 6 of Set 3 | khani
# Processing Record 7 of Set 3 | miri
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | bonavista
# Processing Record 12 of Set 3 | vestmanna
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | iracoubo
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | alcudia
# Processing Record 19 of Set 3 | acapulco
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | semnan
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | sept-iles
# Processing Record 24 of Set 3 | aklavik
# Processing Record 25 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 26 of Set 3 | guiratinga
# Processing Record 27 of Set 3 | sistranda
# Processing Record 28 of Set 3 | hami
# Processing Record 29 of Set 3 | severo-kurilsk
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | margate
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | moerai
# Processing Record 37 of Set 3 | olot
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | san-pedro
# Processing Record 41 of Set 3 | alta floresta
# Processing Record 42 of Set 3 | grindavik
# Processing Record 43 of Set 3 | vao
# Processing Record 44 of Set 3 | whitehorse
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | gamba
# Processing Record 47 of Set 3 | freeport
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | hanmer springs
# Processing Record 50 of Set 3 | vila franca do campo
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | puerto carreno
# Processing Record 3 of Set 4 | inta
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | rawson
# Processing Record 6 of Set 4 | coihaique
# Processing Record 7 of Set 4 | tomatlan
# Processing Record 8 of Set 4 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | lakes entrance
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | resistencia
# Processing Record 12 of Set 4 | mehamn
# Processing Record 13 of Set 4 | atar
# Processing Record 14 of Set 4 | westport
# Processing Record 15 of Set 4 | saskylakh
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | palmer
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | banjar
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | miyang
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | rio grande
# Processing Record 24 of Set 4 | cabo san lucas
# Processing Record 25 of Set 4 | chinhoyi
# Processing Record 26 of Set 4 | ambilobe
# Processing Record 27 of Set 4 | saint-augustin
# Processing Record 28 of Set 4 | murray bridge
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | muli
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 4 | santa cruz
# Processing Record 37 of Set 4 | anito
# Processing Record 38 of Set 4 | te horo
# Processing Record 39 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | ketchikan
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | krasnyy kholm
# Processing Record 45 of Set 4 | guerrero negro
# Processing Record 46 of Set 4 | thilogne
# City not found. Skipping...
# Processing Record 47 of Set 4 | druzhba
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 50 of Set 4 | sao joao da barra
# Processing Record 1 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | kamenka
# Processing Record 4 of Set 5 | zhuhai
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | salalah
# Processing Record 7 of Set 5 | mana
# Processing Record 8 of Set 5 | malaya purga
# Processing Record 9 of Set 5 | kailua
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | bousso
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | sorong
# Processing Record 14 of Set 5 | atlantic beach
# Processing Record 15 of Set 5 | alakurtti
# Processing Record 16 of Set 5 | antofagasta
# Processing Record 17 of Set 5 | luanda
# Processing Record 18 of Set 5 | saint-joseph
# Processing Record 19 of Set 5 | aksarka
# Processing Record 20 of Set 5 | mezen
# Processing Record 21 of Set 5 | zaysan
# Processing Record 22 of Set 5 | port said
# Processing Record 23 of Set 5 | bedford
# Processing Record 24 of Set 5 | ust-kuyga
# Processing Record 25 of Set 5 | salinopolis
# Processing Record 26 of Set 5 | la peca
# Processing Record 27 of Set 5 | paungde
# Processing Record 28 of Set 5 | baruun-urt
# Processing Record 29 of Set 5 | cradock
# Processing Record 30 of Set 5 | menongue
# Processing Record 31 of Set 5 | dukat
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | keffi
# Processing Record 34 of Set 5 | tocopilla
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | severnyy
# Processing Record 37 of Set 5 | nome
# Processing Record 38 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 5 | geraldton
# Processing Record 40 of Set 5 | papara
# Processing Record 41 of Set 5 | eyl
# Processing Record 42 of Set 5 | blagoyevo
# Processing Record 43 of Set 5 | tutoia
# Processing Record 44 of Set 5 | troutdale
# Processing Record 45 of Set 5 | redhakhol
# City not found. Skipping...
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | bayir
# Processing Record 48 of Set 5 | liuzhou
# Processing Record 49 of Set 5 | yelan-koleno
# Processing Record 50 of Set 5 | sitka
# Processing Record 1 of Set 6 | gawler
# Processing Record 2 of Set 6 | tautira
# Processing Record 3 of Set 6 | clyde river
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | kachug
# Processing Record 6 of Set 6 | hofn
# Processing Record 7 of Set 6 | san cristobal
# Processing Record 8 of Set 6 | ziro
# Processing Record 9 of Set 6 | torbay
# Processing Record 10 of Set 6 | brenham
# Processing Record 11 of Set 6 | provideniya
# Processing Record 12 of Set 6 | marsa matruh
# Processing Record 13 of Set 6 | tombouctou
# Processing Record 14 of Set 6 | liverpool
# Processing Record 15 of Set 6 | atherton
# Processing Record 16 of Set 6 | goreloye
# Processing Record 17 of Set 6 | mount isa
# Processing Record 18 of Set 6 | arlit
# Processing Record 19 of Set 6 | beyneu
# Processing Record 20 of Set 6 | ulagan
# Processing Record 21 of Set 6 | broome
# Processing Record 22 of Set 6 | alice springs
# Processing Record 23 of Set 6 | outlook
# Processing Record 24 of Set 6 | yakeshi
# Processing Record 25 of Set 6 | san patricio
# Processing Record 26 of Set 6 | woodstock
# Processing Record 27 of Set 6 | atikokan
# Processing Record 28 of Set 6 | japura
# Processing Record 29 of Set 6 | strasshof
# City not found. Skipping...
# Processing Record 30 of Set 6 | richards bay
# Processing Record 31 of Set 6 | cheremshan
# Processing Record 32 of Set 6 | marathon
# Processing Record 33 of Set 6 | nsanje
# Processing Record 34 of Set 6 | gazimurskiy zavod
# Processing Record 35 of Set 6 | zirandaro
# Processing Record 36 of Set 6 | cuiluan
# Processing Record 37 of Set 6 | shu
# Processing Record 38 of Set 6 | virginia beach
# Processing Record 39 of Set 6 | karratha
# Processing Record 40 of Set 6 | deori khas
# Processing Record 41 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 6 | nisia floresta
# Processing Record 43 of Set 6 | sheridan
# Processing Record 44 of Set 6 | lovozero
# Processing Record 45 of Set 6 | natal
# Processing Record 46 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 6 | alofi
# Processing Record 48 of Set 6 | vrangel
# Processing Record 49 of Set 6 | impfondo
# Processing Record 50 of Set 6 | okhotsk
# Processing Record 1 of Set 7 | yenagoa
# Processing Record 2 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 7 | eureka
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 7 | mbandaka
# Processing Record 7 of Set 7 | davila
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | north myrtle beach
# Processing Record 11 of Set 7 | katangli
# Processing Record 12 of Set 7 | hualmay
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | tiarei
# Processing Record 15 of Set 7 | changli
# Processing Record 16 of Set 7 | vestmannaeyjar
# Processing Record 17 of Set 7 | nemuro
# Processing Record 18 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 7 | lloydminster
# Processing Record 20 of Set 7 | haines junction
# Processing Record 21 of Set 7 | hambantota
# Processing Record 22 of Set 7 | san policarpo
# Processing Record 23 of Set 7 | fort saint james
# Processing Record 24 of Set 7 | talah
# City not found. Skipping...
# Processing Record 25 of Set 7 | jiazi
# Processing Record 26 of Set 7 | berikulskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | sann
# Processing Record 28 of Set 7 | upata
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 7 | filadelfia
# Processing Record 32 of Set 7 | aviles
# Processing Record 33 of Set 7 | lapua
# Processing Record 34 of Set 7 | hopelchen
# Processing Record 35 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | ola
# Processing Record 38 of Set 7 | kurkino
# Processing Record 39 of Set 7 | barcelona
# Processing Record 40 of Set 7 | shelburne
# Processing Record 41 of Set 7 | fortuna
# Processing Record 42 of Set 7 | souillac
# Processing Record 43 of Set 7 | autazes
# Processing Record 44 of Set 7 | narino
# Processing Record 45 of Set 7 | padang
# Processing Record 46 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 7 | tamasi
# Processing Record 48 of Set 7 | lagoa
# Processing Record 49 of Set 7 | trincomalee
# Processing Record 50 of Set 7 | beloha
# Processing Record 1 of Set 8 | kabo
# Processing Record 2 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 8 | arandis
# Processing Record 4 of Set 8 | rocha
# Processing Record 5 of Set 8 | pampa
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | casimcea
# Processing Record 8 of Set 8 | rafaela
# Processing Record 9 of Set 8 | tual
# Processing Record 10 of Set 8 | fomento
# Processing Record 11 of Set 8 | dubuque
# Processing Record 12 of Set 8 | auki
# Processing Record 13 of Set 8 | port hardy
# Processing Record 14 of Set 8 | solnechnyy
# Processing Record 15 of Set 8 | alyangula
# Processing Record 16 of Set 8 | saldanha
# Processing Record 17 of Set 8 | plainview
# Processing Record 18 of Set 8 | walvis bay
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | norman wells
# Processing Record 21 of Set 8 | marienburg
# Processing Record 22 of Set 8 | tenenkou
# Processing Record 23 of Set 8 | emba
# Processing Record 24 of Set 8 | olafsvik
# Processing Record 25 of Set 8 | makung
# City not found. Skipping...
# Processing Record 26 of Set 8 | talaya
# Processing Record 27 of Set 8 | kruisfontein
# Processing Record 28 of Set 8 | nara
# Processing Record 29 of Set 8 | coolum beach
# Processing Record 30 of Set 8 | riverton
# Processing Record 31 of Set 8 | saquena
# Processing Record 32 of Set 8 | kolar
# Processing Record 33 of Set 8 | axim
# Processing Record 34 of Set 8 | port blair
# Processing Record 35 of Set 8 | vallenar
# Processing Record 36 of Set 8 | auburn
# Processing Record 37 of Set 8 | uspenka
# Processing Record 38 of Set 8 | ankazoabo
# Processing Record 39 of Set 8 | nizhneangarsk
# Processing Record 40 of Set 8 | kolokani
# Processing Record 41 of Set 8 | ahipara
# Processing Record 42 of Set 8 | chulym
# Processing Record 43 of Set 8 | sobolevo
# Processing Record 44 of Set 8 | kashi
# Processing Record 45 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 8 | thunder bay
# Processing Record 47 of Set 8 | nantucket
# Processing Record 48 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 8 | placerville
# Processing Record 50 of Set 8 | kuching
# Processing Record 1 of Set 9 | plettenberg
# Processing Record 2 of Set 9 | fairbanks
# Processing Record 3 of Set 9 | saint-pierre
# Processing Record 4 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 9 | greymouth
# Processing Record 6 of Set 9 | korla
# Processing Record 7 of Set 9 | tommot
# Processing Record 8 of Set 9 | bubaque
# Processing Record 9 of Set 9 | narsaq
# Processing Record 10 of Set 9 | fohnsdorf
# Processing Record 11 of Set 9 | tanete
# Processing Record 12 of Set 9 | cayenne
# Processing Record 13 of Set 9 | avesta
# Processing Record 14 of Set 9 | aitape
# Processing Record 15 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 16 of Set 9 | chapleau
# Processing Record 17 of Set 9 | nioro
# Processing Record 18 of Set 9 | havoysund
# Processing Record 19 of Set 9 | north battleford
# Processing Record 20 of Set 9 | sabha
# Processing Record 21 of Set 9 | tortoli
# Processing Record 22 of Set 9 | bucium
# Processing Record 23 of Set 9 | vitim
# Processing Record 24 of Set 9 | kampong cham
# Processing Record 25 of Set 9 | jalingo
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | macara
# Processing Record 28 of Set 9 | santiago del estero
# Processing Record 29 of Set 9 | waipawa
# Processing Record 30 of Set 9 | anjozorobe
# Processing Record 31 of Set 9 | ancud
# Processing Record 32 of Set 9 | austin
# Processing Record 33 of Set 9 | bregovo
# Processing Record 34 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 35 of Set 9 | cockburn town
# Processing Record 36 of Set 9 | vilyuysk
# Processing Record 37 of Set 9 | bilibino
# Processing Record 38 of Set 9 | dunedin
# Processing Record 39 of Set 9 | sindon
# Processing Record 40 of Set 9 | neijiang
# Processing Record 41 of Set 9 | borna
# Processing Record 42 of Set 9 | harrisonburg
# Processing Record 43 of Set 9 | teya
# Processing Record 44 of Set 9 | tres arroyos
# Processing Record 45 of Set 9 | jiuquan
# Processing Record 46 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 9 | awbari
# Processing Record 48 of Set 9 | pyinmana
# Processing Record 49 of Set 9 | dingle
# Processing Record 50 of Set 9 | flinders
# Processing Record 1 of Set 10 | obihiro
# Processing Record 2 of Set 10 | high level
# Processing Record 3 of Set 10 | berlevag
# Processing Record 4 of Set 10 | bichura
# Processing Record 5 of Set 10 | shumskiy
# Processing Record 6 of Set 10 | roma
# Processing Record 7 of Set 10 | picui
# Processing Record 8 of Set 10 | itarema
# Processing Record 9 of Set 10 | mackenzie
# Processing Record 10 of Set 10 | burgeo
# Processing Record 11 of Set 10 | phan thiet
# Processing Record 12 of Set 10 | kudahuvadhoo
# Processing Record 13 of Set 10 | la rioja
# Processing Record 14 of Set 10 | tonota
# Processing Record 15 of Set 10 | ejido
# Processing Record 16 of Set 10 | progreso
# Processing Record 17 of Set 10 | kununurra
# Processing Record 18 of Set 10 | de-kastri
# Processing Record 19 of Set 10 | gwembe
# Processing Record 20 of Set 10 | marshfield
# Processing Record 21 of Set 10 | araouane
# Processing Record 22 of Set 10 | katobu
# Processing Record 23 of Set 10 | elizabeth city
# Processing Record 24 of Set 10 | nelson bay
# Processing Record 25 of Set 10 | novobirilyussy
# Processing Record 26 of Set 10 | dobryanka
# Processing Record 27 of Set 10 | jiexiu
# Processing Record 28 of Set 10 | lashio
# Processing Record 29 of Set 10 | hasaki
# Processing Record 30 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 10 | boyolangu
# Processing Record 32 of Set 10 | vardo
# Processing Record 33 of Set 10 | nipawin
# Processing Record 34 of Set 10 | luganville
# Processing Record 35 of Set 10 | meulaboh
# Processing Record 36 of Set 10 | zhangye
# Processing Record 37 of Set 10 | bathsheba
# Processing Record 38 of Set 10 | bassila
# Processing Record 39 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | mitsamiouli
# Processing Record 41 of Set 10 | russell
# Processing Record 42 of Set 10 | bilecik
# Processing Record 43 of Set 10 | bansko
# Processing Record 44 of Set 10 | lorengau
# Processing Record 45 of Set 10 | blairmore
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | guaymas
# Processing Record 48 of Set 10 | mae sai
# Processing Record 49 of Set 10 | maragogi
# Processing Record 50 of Set 10 | lebu
# Processing Record 1 of Set 11 | ugoofaaru
# Processing Record 2 of Set 11 | ayan
# Processing Record 3 of Set 11 | cherskiy
# Processing Record 4 of Set 11 | lebork
# Processing Record 5 of Set 11 | kavaratti
# Processing Record 6 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 7 of Set 11 | islip
# Processing Record 8 of Set 11 | lyubymivka
# Processing Record 9 of Set 11 | shingu
# Processing Record 10 of Set 11 | saint-francois
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | moindou
# Processing Record 13 of Set 11 | bada
# Processing Record 14 of Set 11 | henderson
# Processing Record 15 of Set 11 | usinsk
# Processing Record 16 of Set 11 | yomou
# Processing Record 17 of Set 11 | murdochville
# Processing Record 18 of Set 11 | las choapas
# Processing Record 19 of Set 11 | kaputa
# Processing Record 20 of Set 11 | aksu
# Processing Record 21 of Set 11 | tura
# Processing Record 22 of Set 11 | kundiawa
# Processing Record 23 of Set 11 | griffith
# Processing Record 24 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 25 of Set 11 | ourem
# Processing Record 26 of Set 11 | nago
# Processing Record 27 of Set 11 | komsomolskiy
# Processing Record 28 of Set 11 | paamiut
# Processing Record 29 of Set 11 | andenes
# Processing Record 30 of Set 11 | tezu
# Processing Record 31 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 11 | arrifes
# Processing Record 34 of Set 11 | pitimbu
# Processing Record 35 of Set 11 | charlottetown
# Processing Record 36 of Set 11 | faya
# Processing Record 37 of Set 11 | sola
# Processing Record 38 of Set 11 | aykhal
# Processing Record 39 of Set 11 | launceston
# Processing Record 40 of Set 11 | kidal
# Processing Record 41 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 11 | ixtapa
# Processing Record 43 of Set 11 | labuan
# Processing Record 44 of Set 11 | adre
# Processing Record 45 of Set 11 | lincoln
# Processing Record 46 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 47 of Set 11 | kahului
# Processing Record 48 of Set 11 | huarmey
# Processing Record 49 of Set 11 | port-gentil
# Processing Record 50 of Set 11 | lyubinskiy
# Processing Record 1 of Set 12 | iowa city
# Processing Record 2 of Set 12 | nuuk
# Processing Record 3 of Set 12 | edd
# Processing Record 4 of Set 12 | wattegama
# Processing Record 5 of Set 12 | quatre cocos
# Processing Record 6 of Set 12 | husavik
# Processing Record 7 of Set 12 | ndele
# Processing Record 8 of Set 12 | oranjemund
# Processing Record 9 of Set 12 | socuellamos
# Processing Record 10 of Set 12 | jumla
# Processing Record 11 of Set 12 | zhezkazgan
# Processing Record 12 of Set 12 | gat
# Processing Record 13 of Set 12 | kalaleh
# Processing Record 14 of Set 12 | balkanabat
# Processing Record 15 of Set 12 | tessalit
# Processing Record 16 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 17 of Set 12 | yuci
# Processing Record 18 of Set 12 | bozeman
# Processing Record 19 of Set 12 | yarada
# Processing Record 20 of Set 12 | tulun
# Processing Record 21 of Set 12 | mecca
# Processing Record 22 of Set 12 | yanam
# Processing Record 23 of Set 12 | san quintin
# Processing Record 24 of Set 12 | verkhoyansk
# Processing Record 25 of Set 12 | rosetta
# Processing Record 26 of Set 12 | okha
# Processing Record 27 of Set 12 | morgan city
# Processing Record 28 of Set 12 | punakha
# Processing Record 29 of Set 12 | maceio
# Processing Record 30 of Set 12 | neiafu
# Processing Record 31 of Set 12 | kasamwa
# Processing Record 32 of Set 12 | gladstone
# Processing Record 33 of Set 12 | yuzhno-kurilsk
# Processing Record 34 of Set 12 | farsund
# Processing Record 35 of Set 12 | joshimath
# Processing Record 36 of Set 12 | sena madureira
# Processing Record 37 of Set 12 | west des moines
# Processing Record 38 of Set 12 | peleduy
# Processing Record 39 of Set 12 | kerman
# Processing Record 40 of Set 12 | yulara
# Processing Record 41 of Set 12 | ballina
# Processing Record 42 of Set 12 | valdivia
# Processing Record 43 of Set 12 | tucuman
# Processing Record 44 of Set 12 | xudat
# Processing Record 45 of Set 12 | mogok
# Processing Record 46 of Set 12 | agadir
# Processing Record 47 of Set 12 | montbrison
# Processing Record 48 of Set 12 | giyani
# Processing Record 49 of Set 12 | agirish
# Processing Record 50 of Set 12 | poole
# Processing Record 1 of Set 13 | ushirombo
# Processing Record 2 of Set 13 | galesong
# Processing Record 3 of Set 13 | samarai
# Processing Record 4 of Set 13 | turukhansk
# Processing Record 5 of Set 13 | uvat
# Processing Record 6 of Set 13 | saurimo
# Processing Record 7 of Set 13 | presidencia roque saenz pena
# Processing Record 8 of Set 13 | nanae
# Processing Record 9 of Set 13 | champerico
# Processing Record 10 of Set 13 | nyurba
# Processing Record 11 of Set 13 | yaounde
# Processing Record 12 of Set 13 | teeli
# Processing Record 13 of Set 13 | castries
# Processing Record 14 of Set 13 | takoradi
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | road town
# Processing Record 17 of Set 13 | uppsala
# Processing Record 18 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 19 of Set 13 | peniche
# Processing Record 20 of Set 13 | tabou
# Processing Record 21 of Set 13 | torres
# Processing Record 22 of Set 13 | zambezi
# Processing Record 23 of Set 13 | esik
# Processing Record 24 of Set 13 | arman
# Processing Record 25 of Set 13 | coalinga
# Processing Record 26 of Set 13 | skibbereen
# Processing Record 27 of Set 13 | orlik
# Processing Record 28 of Set 13 | champasak
# Processing Record 29 of Set 13 | tadine
# Processing Record 30 of Set 13 | salamiyah
# Processing Record 31 of Set 13 | port keats
# Processing Record 32 of Set 13 | bor
# Processing Record 33 of Set 13 | turinsk
# Processing Record 34 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 13 | keetmanshoop
# Processing Record 36 of Set 13 | nanortalik
# Processing Record 37 of Set 13 | ifanadiana
# Processing Record 38 of Set 13 | ahuimanu
# Processing Record 39 of Set 13 | sioux lookout
# Processing Record 40 of Set 13 | hirara
# Processing Record 41 of Set 13 | iwanai
# Processing Record 42 of Set 13 | naze
# Processing Record 43 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 44 of Set 13 | quincy
# Processing Record 45 of Set 13 | north bend
# Processing Record 46 of Set 13 | coffs harbour
# Processing Record 47 of Set 13 | marystown
# Processing Record 48 of Set 13 | yuncheng
# Processing Record 49 of Set 13 | dakar
# Processing Record 50 of Set 13 | susurluk
# Processing Record 1 of Set 14 | pinhao
# Processing Record 2 of Set 14 | alekseyevka
# Processing Record 3 of Set 14 | qasigiannguit
# Processing Record 4 of Set 14 | mkushi
# Processing Record 5 of Set 14 | wels
# Processing Record 6 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 7 of Set 14 | vagay
# Processing Record 8 of Set 14 | kholodnyy
# Processing Record 9 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 14 | general roca
# Processing Record 11 of Set 14 | dalvik
# Processing Record 12 of Set 14 | yavaros
# Processing Record 13 of Set 14 | manokwari
# Processing Record 14 of Set 14 | buala
# Processing Record 15 of Set 14 | homer
# Processing Record 16 of Set 14 | seoul
# Processing Record 17 of Set 14 | marzuq
# Processing Record 18 of Set 14 | chara
# Processing Record 19 of Set 14 | santo amaro da imperatriz
# Processing Record 20 of Set 14 | farmington
# Processing Record 21 of Set 14 | worthing
# Processing Record 22 of Set 14 | kedarnath
# City not found. Skipping...
# Processing Record 23 of Set 14 | leh
# Processing Record 24 of Set 14 | mwinilunga
# Processing Record 25 of Set 14 | bima
# Processing Record 26 of Set 14 | znamensk
# Processing Record 27 of Set 14 | kuryk
# Processing Record 28 of Set 14 | amapa
# Processing Record 29 of Set 14 | karabuk
# Processing Record 30 of Set 14 | port augusta
# Processing Record 31 of Set 14 | agde
# Processing Record 32 of Set 14 | aracruz
# Processing Record 33 of Set 14 | matay
# Processing Record 34 of Set 14 | hai phong
# City not found. Skipping...
# Processing Record 35 of Set 14 | birao
# Processing Record 36 of Set 14 | locri
# Processing Record 37 of Set 14 | cap malheureux
# Processing Record 38 of Set 14 | huautla
# Processing Record 39 of Set 14 | tilichiki
# Processing Record 40 of Set 14 | barzas
# Processing Record 41 of Set 14 | presidente epitacio
# Processing Record 42 of Set 14 | half moon bay
# Processing Record 43 of Set 14 | kendari
# Processing Record 44 of Set 14 | chipinge
# Processing Record 45 of Set 14 | mullovka
# Processing Record 46 of Set 14 | maturin
# Processing Record 47 of Set 14 | san juan de la maguana
# Processing Record 48 of Set 14 | dustlik
# Processing Record 49 of Set 14 | buraydah
# Processing Record 50 of Set 14 | garden city
# Processing Record 1 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 15 | abu kamal
# Processing Record 3 of Set 15 | sharhorod
# Processing Record 4 of Set 15 | tarakan
# Processing Record 5 of Set 15 | laizhou
# Processing Record 6 of Set 15 | severo-yeniseyskiy
# Processing Record 7 of Set 15 | gerash
# Processing Record 8 of Set 15 | balaipungut
# Processing Record 9 of Set 15 | pakwach
# City not found. Skipping...
# Processing Record 10 of Set 15 | ilhabela
# Processing Record 11 of Set 15 | bereda
# Processing Record 12 of Set 15 | santa maria
# Processing Record 13 of Set 15 | imbituba
# Processing Record 14 of Set 15 | huanren
# Processing Record 15 of Set 15 | isiro
# Processing Record 16 of Set 15 | las palmas
# Processing Record 17 of Set 15 | okaihau
# Processing Record 18 of Set 15 | ghanzi
# Processing Record 19 of Set 15 | lubango
# Processing Record 20 of Set 15 | oussouye
# Processing Record 21 of Set 15 | nadym
# Processing Record 22 of Set 15 | sinnamary
# Processing Record 23 of Set 15 | filotion
# Processing Record 24 of Set 15 | hun
# Processing Record 25 of Set 15 | morondava
# Processing Record 26 of Set 15 | buin
# Processing Record 27 of Set 15 | marfino
# Processing Record 28 of Set 15 | venado tuerto
# Processing Record 29 of Set 15 | asyut
# Processing Record 30 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 31 of Set 15 | houma
# Processing Record 32 of Set 15 | inhambane
# Processing Record 33 of Set 15 | valparaiso
# Processing Record 34 of Set 15 | port hedland
# Processing Record 35 of Set 15 | tashtagol
# Processing Record 36 of Set 15 | la roche-sur-yon
# Processing Record 37 of Set 15 | the valley
# Processing Record 38 of Set 15 | carbonia
# Processing Record 39 of Set 15 | kurmanayevka
# Processing Record 40 of Set 15 | am timan
# Processing Record 41 of Set 15 | tottori
# Processing Record 42 of Set 15 | erzin
# Processing Record 43 of Set 15 | puerto del rosario
# Processing Record 44 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 45 of Set 15 | chaoyang
# Processing Record 46 of Set 15 | opuwo
# Processing Record 47 of Set 15 | guaruja
# Processing Record 48 of Set 15 | kloulklubed
# Processing Record 49 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 15 | mogadishu
# Processing Record 1 of Set 16 | salgado
# Processing Record 2 of Set 16 | marv dasht
# City not found. Skipping...
# Processing Record 3 of Set 16 | rancho palos verdes
# Processing Record 4 of Set 16 | shangqiu
# Processing Record 5 of Set 16 | qostanay
# Processing Record 6 of Set 16 | shwebo
# Processing Record 7 of Set 16 | garowe
# Processing Record 8 of Set 16 | charters towers
# Processing Record 9 of Set 16 | tibati
# Processing Record 10 of Set 16 | kaura namoda
# Processing Record 11 of Set 16 | chapais
# Processing Record 12 of Set 16 | bhag
# Processing Record 13 of Set 16 | nichinan
# Processing Record 14 of Set 16 | bowen
# Processing Record 15 of Set 16 | ransang
# Processing Record 16 of Set 16 | kieta
# Processing Record 17 of Set 16 | dano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Luderitz -26.6481   15.1594     68.74        68          41       11.77
# 1       Laguna  38.4210 -121.4238     65.25        72           0        0.00
# 2         Hilo  19.7297 -155.0900     72.81        91          14        1.99
# 3  New Norfolk -42.7826  147.0587     74.66        29           8        3.00
# 4       Albany  42.6001  -73.9662     36.09        89          38        2.37
# 5      Illapel -31.6308  -71.1653     65.03        81           3        2.33
# 6    Carnarvon -24.8667  113.6333     87.58        57          13        6.87
# 7       Ekhabi  53.5102  142.9671     26.91        92         100        8.25
# 8   Mandalgovi  45.7625  106.2708      1.00        55         100       12.50
# 9   Carbondale  37.7273  -89.2168     43.23        78           0        5.75
#
#   Country Current Description
# 0      NA    scattered clouds
# 1      US           clear sky
# 2      US          few clouds
# 3      AU           clear sky
# 4      US    scattered clouds
# 5      CL           clear sky
# 6      AU          few clouds
# 7      RU          light snow
# 8      MN     overcast clouds
# 9      US           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
